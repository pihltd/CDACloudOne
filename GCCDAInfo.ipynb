# %%
from cdapython import *
import pandas as pd
from IPython.display import display, Markdown

# %%
tables()
# Out:
# ['file',
#  'mutation',
#  'observation',
#  'project',
#  'subject',
#  'treatment',
#  'upstream_identifiers']

# %%
cda_functions()
# Out:
# You can get complete usage details for each function by calling "help( function_name )".
# ['tables',
#  'columns',
#  'column_values',
#  'summarize_subjects',
#  'summarize_files',
#  'get_subject_data',
#  'get_file_data',
#  'expand_subject_results',
#  'expand_file_results',
#  'intersect_subject_results',
#  'intersect_file_results',
#  'release_metadata',
#  'get_valid_log_levels',
#  'get_log_level',
#  'set_log_level',
#  'enable_console_logging',
#  'disable_console_logging',
#  'enable_file_logging',
#  'disable_file_logging',
#  'get_api_url',
#  'set_api_url',
#  'cda_functions']

# %%
gcFiles = get_file_data(data_source = 'GC')

# %%
display(Markdown(gcFiles.to_markdown()))
